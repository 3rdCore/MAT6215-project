# %% [markdown]
# Toy datasets idea taken from https://umap-learn.readthedocs.io/en/latest/auto_examples/plot_algorithm_comparison.html and added Diffusion map

# %%
# !pip install umap-learn
# !pip install pyDiffMap
# !pip install seaborn
# Out:
# Requirement already satisfied: umap-learn in d:\programs\miniconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: scipy>=1.0 in d:\programs\miniconda3\lib\site-packages (from umap-learn) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.22 in d:\programs\miniconda3\lib\site-packages (from umap-learn) (1.0.1)
# Requirement already satisfied: tqdm in d:\programs\miniconda3\lib\site-packages (from umap-learn) (4.62.3)
# Requirement already satisfied: numpy>=1.17 in d:\programs\miniconda3\lib\site-packages (from umap-learn) (1.20.3)
# Requirement already satisfied: numba>=0.49 in d:\programs\miniconda3\lib\site-packages (from umap-learn) (0.54.1)
# Requirement already satisfied: pynndescent>=0.5 in d:\programs\miniconda3\lib\site-packages (from umap-learn) (0.5.5)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in d:\programs\miniconda3\lib\site-packages (from numba>=0.49->umap-learn) (0.37.0)
# Requirement already satisfied: setuptools in d:\programs\miniconda3\lib\site-packages (from numba>=0.49->umap-learn) (59.4.0)
# Requirement already satisfied: joblib>=0.11 in d:\programs\miniconda3\lib\site-packages (from pynndescent>=0.5->umap-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\programs\miniconda3\lib\site-packages (from scikit-learn>=0.22->umap-learn) (3.0.0)
# Requirement already satisfied: colorama in d:\programs\miniconda3\lib\site-packages (from tqdm->umap-learn) (0.4.4)
# Requirement already satisfied: pyDiffMap in d:\programs\miniconda3\lib\site-packages (0.2.0.1)
# Requirement already satisfied: scipy in d:\programs\miniconda3\lib\site-packages (from pyDiffMap) (1.7.3)
# Requirement already satisfied: six in d:\programs\miniconda3\lib\site-packages (from pyDiffMap) (1.16.0)
# Requirement already satisfied: matplotlib in d:\programs\miniconda3\lib\site-packages (from pyDiffMap) (3.5.0)
# Requirement already satisfied: numpy in d:\programs\miniconda3\lib\site-packages (from pyDiffMap) (1.20.3)
# Requirement already satisfied: scikit-learn in d:\programs\miniconda3\lib\site-packages (from pyDiffMap) (1.0.1)
# Requirement already satisfied: numexpr in d:\programs\miniconda3\lib\site-packages (from pyDiffMap) (2.8.0)
# Requirement already satisfied: cycler>=0.10 in d:\programs\miniconda3\lib\site-packages (from matplotlib->pyDiffMap) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\programs\miniconda3\lib\site-packages (from matplotlib->pyDiffMap) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in d:\programs\miniconda3\lib\site-packages (from matplotlib->pyDiffMap) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in d:\programs\miniconda3\lib\site-packages (from matplotlib->pyDiffMap) (4.28.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\programs\miniconda3\lib\site-packages (from matplotlib->pyDiffMap) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\programs\miniconda3\lib\site-packages (from matplotlib->pyDiffMap) (3.0.6)
# Requirement already satisfied: pillow>=6.2.0 in d:\programs\miniconda3\lib\site-packages (from matplotlib->pyDiffMap) (8.4.0)
# Requirement already satisfied: setuptools-scm>=4 in d:\programs\miniconda3\lib\site-packages (from matplotlib->pyDiffMap) (6.3.2)
# Requirement already satisfied: joblib>=0.11 in d:\programs\miniconda3\lib\site-packages (from scikit-learn->pyDiffMap) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\programs\miniconda3\lib\site-packages (from scikit-learn->pyDiffMap) (3.0.0)
# Requirement already satisfied: setuptools in d:\programs\miniconda3\lib\site-packages (from setuptools-scm>=4->matplotlib->pyDiffMap) (59.4.0)
# Requirement already satisfied: tomli>=1.0.0 in d:\programs\miniconda3\lib\site-packages (from setuptools-scm>=4->matplotlib->pyDiffMap) (1.2.2)
# Requirement already satisfied: seaborn in d:\programs\miniconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in d:\programs\miniconda3\lib\site-packages (from seaborn) (3.5.0)
# Requirement already satisfied: scipy>=1.0 in d:\programs\miniconda3\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: numpy>=1.15 in d:\programs\miniconda3\lib\site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: pandas>=0.23 in d:\programs\miniconda3\lib\site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: fonttools>=4.22.0 in d:\programs\miniconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.28.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\programs\miniconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\programs\miniconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\programs\miniconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in d:\programs\miniconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\programs\miniconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in d:\programs\miniconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: setuptools-scm>=4 in d:\programs\miniconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (6.3.2)
# Requirement already satisfied: pytz>=2017.3 in d:\programs\miniconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in d:\programs\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: setuptools in d:\programs\miniconda3\lib\site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (59.4.0)
# Requirement already satisfied: tomli>=1.0.0 in d:\programs\miniconda3\lib\site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (1.2.2)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time


from sklearn import datasets, decomposition, manifold, preprocessing
from colorsys import hsv_to_rgb

import umap
from pydiffmap import diffusion_map as dm

# %%
sns.set(context="paper", style="white")

blobs, blob_labels = datasets.make_blobs(
    n_samples=500, n_features=10, centers=5, random_state=42
)
iris = datasets.load_iris()
digits = datasets.load_digits(n_class=10)
wine = datasets.load_wine()
swissroll, swissroll_labels = datasets.make_swiss_roll(
    n_samples=1000, noise=0.1, random_state=42
)
sphere = np.random.normal(size=(600, 3))
sphere = preprocessing.normalize(sphere)
sphere_hsv = np.array(
    [
        (
            (np.arctan2(c[1], c[0]) + np.pi) / (2 * np.pi),
            np.abs(c[2]),
            min((c[2] + 1.1), 1.0),
        )
        for c in sphere
    ]
)
sphere_colors = np.array([hsv_to_rgb(*c) for c in sphere_hsv])

epsilon = 10
length_scale =np.sqrt(epsilon/2)
kernel = 1.0 * RBF(length_scale)
t_max= 50

reducers = [
    (manifold.TSNE, { 'n_components':2, "perplexity": 50}),
    #(manifold.LocallyLinearEmbedding, {'n_neighbors':10, 'method':'hessian'}),
    (manifold.Isomap, { 'n_components':2, "n_neighbors": 30}), # Automatically select the shortest path algo
    (manifold.MDS, {'n_components':2}), # non metric MDS
    (decomposition.PCA, {'n_components':2}),
    (umap.UMAP, {'n_components':2,"n_neighbors": 30, "min_dist": 0.3}),
    (dm.DiffusionMap.from_sklearn,{'n_evecs':2, 'k': 200, 'epsilon': 'bgh_generous', 'alpha': 1.0, 'neighbor_params':{'n_jobs': -1, 'algorithm': 'ball_tree'}}),
    (DiffusionDistance,{'kernel':kernel, 't_max' : t_max})
]

test_data = [
    (blobs, blob_labels),
    (iris.data, iris.target),
    (digits.data, digits.target),
    (wine.data, wine.target),
    (swissroll, swissroll_labels),
    (sphere, sphere_colors),
]
dataset_names = ["Blobs", "Iris", "Digits", "Wine", "Swiss Roll", "Sphere"]
#dataset_names = [ "Digits","Swiss Roll"]

n_rows = len(test_data)
n_cols = len(reducers)
ax_index = 1
ax_list = []

# plt.figure(figsize=(9 * 2 + 3, 12.5))
plt.figure(figsize=(10, 8))
plt.subplots_adjust(
    left=0.02, right=0.98, bottom=0.001, top=0.96, wspace=0.05, hspace=0.01
)
for data, labels in test_data:
    for reducer, args in reducers:
        start_time = time.time()
        embedding = reducer(**args).fit_transform(data)
        elapsed_time = time.time() - start_time
        ax = plt.subplot(n_rows, n_cols, ax_index)
        if isinstance(labels[0], tuple):
            ax.scatter(*embedding.T, s=10, c=labels, alpha=0.5)
        else:
            ax.scatter(*embedding.T, s=10, c=labels, cmap="Spectral", alpha=0.5)
        ax.text(
            0.99,
            0.01,
            "{:.2f} s".format(elapsed_time),
            transform=ax.transAxes,
            size=14,
            horizontalalignment="right",
        )
        ax_list.append(ax)
        ax_index += 1
plt.setp(ax_list, xticks=[], yticks=[])
# Out:
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_isomap.py:322: UserWarning: The number of connected components of the neighbors graph is 5 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# D:\Programs\miniconda3\lib\site-packages\scipy\sparse\_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# D:\Programs\miniconda3\lib\site-packages\scipy\sparse\_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# D:\Programs\miniconda3\lib\site-packages\scipy\sparse\_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# D:\Programs\miniconda3\lib\site-packages\scipy\sparse\_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# D:\Programs\miniconda3\lib\site-packages\scipy\sparse\_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# D:\Programs\miniconda3\lib\site-packages\scipy\sparse\_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# D:\Programs\miniconda3\lib\site-packages\scipy\sparse\_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# D:\Programs\miniconda3\lib\site-packages\scipy\sparse\_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# D:\Programs\miniconda3\lib\site-packages\scipy\sparse\_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# D:\Programs\miniconda3\lib\site-packages\scipy\sparse\_index.py:82: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_mds.py:517: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_mds.py:517: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_mds.py:517: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_mds.py:517: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_mds.py:517: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_mds.py:517: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn(
# []

# %% [markdown]
# ## Test of the DiffusionDistance class

# %%
from sklearn.gaussian_process.kernels import RBF
from DiffusionDistance import DiffusionDistance

X, y = datasets.load_iris(return_X_y=True)

DD = DiffusionDistance(kernel, 3)
    
embedding = DD.fit_transform(X)
# Out:
# D:\Programs\miniconda3\lib\site-packages\sklearn\manifold\_mds.py:517: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn(
